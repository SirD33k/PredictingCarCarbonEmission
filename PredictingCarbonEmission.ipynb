# %%
#Importing Necessary Libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Loading the Dataset

df = pd.read_csv("MY2023 Fuel Consumption Ratings.csv")
df.head()
# Out:
#    Year   Make              Model  Vehicle Class  Engine Size (L)  Cylinders  \
# 0  2023  Acura            Integra      Full-size              1.5        4.0
# 1  2023  Acura     Integra A-SPEC      Full-size              1.5        4.0
# 2  2023  Acura     Integra A-SPEC      Full-size              1.5        4.0
# 3  2023  Acura         MDX SH-AWD     SUV: Small              3.5        6.0
# 4  2023  Acura  MDX SH-AWD Type S  SUV: Standard              3.0        6.0
#
#   Transmission Fuel Type  Fuel Consumption (City) (L/100 km)  \
# 0          AV7         Z                                 7.9
# 1          AV7         Z                                 8.1
# 2           M6         Z                                 8.9
# 3         AS10         Z                                12.6
# 4         AS10         Z                                13.8
#
#    Fuel Consumption (Hwy) (L/100 km)  Fuel Consumption (Comb) (L/100 km)  \
# ...

# %%
df.tail()
# Out:
#                  Year                                               Make  \
# 851               NaN                                    N = natural gas
# 852  Fuel consumption  City and highway fuel consumption ratings are ...
# 853     CO2 emissions  the tailpipe emissions of carbon dioxide (in g...
# 854        CO2 rating  the tailpipe emissions of carbon dioxide rated...
# 855       Smog rating  the tailpipe emissions of smog-forming polluta...
#
#     Model Vehicle Class  Engine Size (L)  Cylinders Transmission Fuel Type  \
# 851   NaN           NaN              NaN        NaN          NaN       NaN
# 852   NaN           NaN              NaN        NaN          NaN       NaN
# 853   NaN           NaN              NaN        NaN          NaN       NaN
# 854   NaN           NaN              NaN        NaN          NaN       NaN
# 855   NaN           NaN              NaN        NaN          NaN       NaN
#
# ...

# %%
#Exploring Dataset Information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 856 entries, 0 to 855
# Data columns (total 15 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Year                                841 non-null    object
#  1   Make                                854 non-null    object
#  2   Model                               833 non-null    object
#  3   Vehicle Class                       833 non-null    object
#  4   Engine Size (L)                     833 non-null    float64
#  5   Cylinders                           833 non-null    float64
#  6   Transmission                        833 non-null    object
#  7   Fuel Type                           833 non-null    object
#  8   Fuel Consumption (City) (L/100 km)  833 non-null    float64
#  9   Fuel Consumption (Hwy) (L/100 km)   833 non-null    float64
#  10  Fuel Consumption (Comb) (L/100 km)  833 non-null    float64
# ...

# %%
#Exploring Dataset Description

df.describe()
# Out:
#        Engine Size (L)   Cylinders  Fuel Consumption (City) (L/100 km)  \
# count       833.000000  833.000000                          833.000000
# mean          3.147899    5.627851                           12.431453
# std           1.353076    1.968695                            3.456191
# min           1.200000    3.000000                            4.400000
# 25%           2.000000    4.000000                           10.100000
# 50%           3.000000    6.000000                           12.100000
# 75%           3.600000    6.000000                           14.600000
# max           8.000000   16.000000                           30.300000
#
#        Fuel Consumption (Hwy) (L/100 km)  Fuel Consumption (Comb) (L/100 km)  \
# count                         833.000000                          833.000000
# mean                            9.353661                           11.047179
# std                             2.302312                            2.878308
# ...

# %%
#Exploring Dataset Shape

df.shape
# Out:
# (856, 15)

# %%
#Exploring Dataset NaN values

df.isna().sum()
# Out:
# Year                                  15
# Make                                   2
# Model                                 23
# Vehicle Class                         23
# Engine Size (L)                       23
# Cylinders                             23
# Transmission                          23
# Fuel Type                             23
# Fuel Consumption (City) (L/100 km)    23
# Fuel Consumption (Hwy) (L/100 km)     23
# Fuel Consumption (Comb) (L/100 km)    23
# Fuel Consumption (Comb) (mpg)         23
# CO2 Emissions (g/km)                  23
# CO2 Rating                            23
# Smog Rating                           23
# dtype: int64

# %%
#Exploring Dataset Column

df.columns
# Out:
# Index(['Year', 'Make', 'Model', 'Vehicle Class', 'Engine Size (L)',
#        'Cylinders', 'Transmission', 'Fuel Type',
#        'Fuel Consumption (City) (L/100 km)',
#        'Fuel Consumption (Hwy) (L/100 km)',
#        'Fuel Consumption (Comb) (L/100 km)', 'Fuel Consumption (Comb) (mpg)',
#        'CO2 Emissions (g/km)', 'CO2 Rating', 'Smog Rating'],
#       dtype='object')

# %%
#Exploring Dataset Make

df['Make'].unique()
# Out:
# array(['Acura', 'Alfa Romeo', 'Aston Martin', 'Audi', 'Bentley', 'BMW',
#        'Bugatti', 'Buick', 'Cadillac', 'Chevrolet', 'Chrysler', 'Dodge',
#        'FIAT', 'Ford', 'Genesis', 'GMC', 'Honda', 'Hyundai', 'Infiniti',
#        'Jaguar', 'Jeep', 'Kia', 'Lamborghini', 'Land Rover', 'Lexus',
#        'Lincoln', 'Maserati', 'Mazda', 'Mercedes-Benz', 'MINI',
#        'Mitsubishi', 'Nissan', 'Porsche', 'Ram', 'Rolls-Royce', 'Subaru',
#        'Toyota', 'Volkswagen', 'Volvo', nan, '4WD/4X4 = Four-wheel drive',
#        'AWD = All-wheel drive', 'FFV = Flexible-fuel vehicle',
#        'SWB = Short wheelbase', 'LWB = Long wheelbase',
#        'EWB = Extended wheelbase', 'A = automatic',
#        'AM = automated manual', 'AS = automatic with select shift',
#        'AV = continuously variable', 'M = manual',
#        '3 � 10 = Number of gears', 'X = regular gasoline',
#        'Z = premium gasoline', 'D = diesel', 'E = ethanol (E85)',
#        'N = natural gas',
# ...

# %%
#Exploring Make of cars that doesn't make any sense

valid_makes = ['Acura', 'Alfa Romeo', 'Aston Martin', 'Audi', 'Bentley', 'BMW',
       'Bugatti', 'Buick', 'Cadillac', 'Chevrolet', 'Chrysler', 'Dodge',
       'FIAT', 'Ford', 'Genesis', 'GMC', 'Honda', 'Hyundai', 'Infiniti',
       'Jaguar', 'Jeep', 'Kia', 'Lamborghini', 'Land Rover', 'Lexus',
       'Lincoln', 'Maserati', 'Mazda', 'Mercedes-Benz', 'MINI',
       'Mitsubishi', 'Nissan', 'Porsche', 'Ram', 'Rolls-Royce', 'Subaru',
       'Toyota', 'Volkswagen', 'Volvo']

# %%
# Filter out the Make outliers

df1 = df[df['Make'].isin(valid_makes)]

# %%
#Exploring Dataset Distribution of Make

sns.countplot(x=df1['Make'])
plt.xticks(rotation=90)
plt.title("Distribution of Make")
plt.show()

# %%
#Exploring Distribution of Vehicle Class

sns.countplot(x=df1['Vehicle Class'])
plt.xticks(rotation=90)
plt.title("Distribution of Vehicle Class")
plt.show()

# %%
#Exploring Distribution of Engine Class

sns.countplot(x=df1['Engine Size (L)'])
plt.xticks(rotation=90)
plt.title("Distribution of Engine Class")
plt.show()

# %%
#Exploring Distribution of Cylinders

sns.countplot(x=df1['Cylinders'])
plt.xticks(rotation=90)
plt.title("Distribution of # Cylinders")
plt.show()

# %%
#Exploring Distribution of Transmission

sns.countplot(x=df1['Transmission'])
plt.xticks(rotation=90)
plt.title("Distribution of Transmission")
plt.show()

# %%
#Exploring Distribution of Fuel Type

sns.countplot(x=df1['Fuel Type'])
plt.title("Distribution of Fuel Type")
plt.show()

# %%
#Exploring Distribution of CO2 Emissions

sns.histplot(x=df1['CO2 Emissions (g/km)'])
plt.xticks(rotation=90)
plt.title("Distribution of CO2 Emissions")
plt.show()

# %%
#Exploring Distribution of CO2 Rating

sns.countplot(x=df1['CO2 Rating'])
plt.xticks(rotation=90)
plt.title("Distribution of CO2 Rating")
plt.show()

# %%
#Exploring Correlation and Depedencies between numeric column variables

sns.heatmap(df1.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation and Depedencies between numeric column variables")
plt.show()

# %%
#Exploring Distribution of CO2 Emissions by CO2 Rating

sns.histplot(data=df1, x="CO2 Emissions (g/km)", hue="CO2 Rating")
plt.xticks(rotation=90)
plt.title("Distribution of CO2 Emissions by CO2 Rating")
plt.show()

# %%
#Exploring Distribution of CO2 Emissions by CO2 Rating

sns.scatterplot(data=df1, x="CO2 Emissions (g/km)", y="CO2 Rating")
plt.xticks(rotation=90)
plt.title("Distribution of CO2 Emissions by CO2 Rating")
plt.show()

# %%
# Group the data by 'Make' and calculate the sum of 'CO2 Emissions (g/km)' and 'Engine Size (L)'
carbon_per_liter = df1.groupby('Make').agg({'CO2 Emissions (g/km)': 'sum', 'Engine Size (L)': 'sum'})

# Calculate the total carbon emissions per liter for each make
carbon_per_liter['Carbon Emission per Liter'] = carbon_per_liter['CO2 Emissions (g/km)'] / carbon_per_liter['Engine Size (L)']

# Reset index to make 'Make' a column
carbon_per_liter.reset_index(inplace=True)

# Display the result
carbon_per_liter
# Out:
#              Make  CO2 Emissions (g/km)  Engine Size (L)  \
# 0           Acura                2265.0             22.0
# 1      Alfa Romeo                1656.0             15.8
# 2    Aston Martin                2198.0             31.6
# 3            Audi               11263.0            131.6
# 4             BMW               13943.0            170.6
# 5         Bentley                3127.0             44.0
# 6         Bugatti                1738.0             24.0
# 7           Buick                1281.0             11.4
# 8        Cadillac                6895.0             83.0
# 9       Chevrolet               15916.0            217.9
# 10       Chrysler                1873.0             30.1
# 11          Dodge                7134.0            124.8
# 12           FIAT                 221.0              1.3
# 13           Ford               25711.0            290.6
# 14            GMC               10868.0            148.4
# ...

# %%
#Exploring Distribution of CO2 Emissions (g/km) Per Liter

sns.barplot(data= carbon_per_liter, x='Make', y='Carbon Emission per Liter')
plt.xticks(rotation=90)
plt.title("CO2 Emissions (g/km) Per Liter")
plt.show()

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.decomposition import TruncatedSVD

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor

# %%
#Define Numeric and Categorical Columns

numeric_columns = ['Engine Size (L)', 'Cylinders', 'Fuel Consumption (City) (L/100 km)', 'Fuel Consumption (Hwy) (L/100 km)',
                   'Fuel Consumption (Comb) (L/100 km)', 'Fuel Consumption (Comb) (mpg)', 'CO2 Emissions (g/km)', 'CO2 Rating', 'Smog Rating']
categorical_columns = ['Year', 'Make', 'Model', 'Vehicle Class', 'Transmission', 'Fuel Type']

# %%
# Impute numeric columns with median
numeric_imputer = SimpleImputer(strategy='median')
df1[numeric_columns] = numeric_imputer.fit_transform(df1[numeric_columns])

# Impute categorical columns with most frequent value
categorical_imputer = SimpleImputer(strategy='most_frequent')
df1[categorical_columns] = categorical_imputer.fit_transform(df1[categorical_columns])

# %%
#Preparing Data for Modeling

X_train = df1.drop(columns="CO2 Emissions (g/km)")
y_train = df1["CO2 Emissions (g/km)"]

# %%
# Classify into Numeric data & Categorical data

numeric_columns = X_train.select_dtypes(exclude='object').columns
categorical_columns = X_train.select_dtypes(include='object').columns

# %%
#Preprocessing Pipelines

numeric_feature = Pipeline(steps=[('handlingmissing', SimpleImputer(strategy='median')), ('scaling', StandardScaler(with_mean=False))])

categorical_feature = Pipeline(steps=[('handlingmissing', SimpleImputer(strategy='most_frequent')), ('encoding', OneHotEncoder()), ('scaling', StandardScaler(with_mean=False))])

processing = ColumnTransformer([('numeric', numeric_feature, numeric_columns),
                                ('cat', categorical_feature, categorical_columns)])

# %%
model1 = Pipeline(steps=[('processing', processing), ("pca", TruncatedSVD(n_components=210, random_state=0)), ('modeling', LinearRegression())])
model1.fit(X_train, y_train)

model2 = Pipeline(steps=[('processing', processing), ("pca", TruncatedSVD(n_components=210, random_state=0)), ('modeling', AdaBoostRegressor())])
model2.fit(X_train, y_train)

model3 = Pipeline(steps=[('processing', processing), ("pca", TruncatedSVD(n_components=210, random_state=0)), ('modeling', GradientBoostingRegressor())])
model3.fit(X_train, y_train)

print("Model 1 R-squared score:", model1.score(X_train, y_train))
print("Model 2 R-squared score:", model2.score(X_train, y_train))
print("Model 3 R-squared score:", model3.score(X_train, y_train))
# Out:
# Model 1 R-squared score: 0.9897268812780565
# Model 2 R-squared score: 0.9498677040223475
# Model 3 R-squared score: 0.9949295930617736
